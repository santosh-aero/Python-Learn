# %% [markdown]
# # Intro to Python, JupyterLab, and Anaconda
# ***

# %% [markdown]
# <img src="./img/intro.png" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# ## Notebook Features

# %% [markdown]
# Text (or __*Markdown*__) cells:

# %% [markdown]
# __*Code*__ cells:

# %% [markdown]
# __*Images*__:
#
# <img src="./img/xkcd.png" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# __*Modules*__: A collection of functionality that can be *imported* and used in your script.

# %% [markdown]
# The way you import a module, like in this xkcd comic, is to use the ``import`` statement. For example:

# %%
# Note: import antigravity will not work if running directly on Coursera platform
